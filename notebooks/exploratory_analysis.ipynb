# %% [markdown]
# # Exploratory Analysis
#
# Starter notebook for inspecting the wound image dataset, validating class balance, and launching baseline experiments.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path('..').resolve()))

from src.utils import load_config

config = load_config(Path('..') / 'configs' / 'baseline_resnet.yaml')
config

# %%
from src.data_loader import scan_image_folder

root_dir = Path('..') / config['data']['root_dir']
samples, class_to_idx = scan_image_folder(root_dir)
len(samples), class_to_idx
